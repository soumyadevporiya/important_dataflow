# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip('name',x[1]))
    return row






import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

with beam.Pipeline(options=options) as p:
  batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ')
          
      ])
      | 'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,0.1)
      
      
      | beam.Map(print))






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:924: FutureWarning: GroupIntoBatches is experimental.
#   return GroupIntoBatches(*_GroupIntoBatchesParams.parse_payload(proto))
# (('INSBI479746850', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), ['oFIDjzDZJ', 'dfkhjgjzDZJ'])
# (('INSBI752381817', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), ['MNpdRhAYv'])
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip

# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip('name',x))
    return row


def insert_key(x):
    return (x[0][0:6],(x[0],x[1]))



import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

with beam.Pipeline(options=options) as p:
  batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ')
          
      ])
      |beam.Map(insert_key)
      |'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,0.1)
      | beam.Map(print))






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:924: FutureWarning: GroupIntoBatches is experimental.
#   return GroupIntoBatches(*_GroupIntoBatchesParams.parse_payload(proto))
# (('INSBI4', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), ['oFIDjzDZJ', 'dfkhjgjzDZJ'])
# (('INSBI7', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), ['MNpdRhAYv'])
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip

# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip(('id','name'),x))
    return row


def insert_key(x):
    return (x[0][0:6],(x[0],x[1]))



import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

with beam.Pipeline(options=options) as p:
  batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ')
          
      ])
      |beam.Map(insert_key)
      |'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,0.1)
      | beam.FlatMap(lambda x: x[1])
      | beam.Map(print))






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:924: FutureWarning: GroupIntoBatches is experimental.
#   return GroupIntoBatches(*_GroupIntoBatchesParams.parse_payload(proto))
# ('INSBI479746850', 'oFIDjzDZJ')
# ('INSBI479746850', 'dfkhjgjzDZJ')
# ('INSBI752381817', 'MNpdRhAYv')
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip

# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip(('id','name'),x))
    return row


def insert_key(x):
    return (x[0][0:6],(x[0],x[1]))



import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

with beam.Pipeline(options=options) as p:
  batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ')
          
      ])
      |beam.Map(insert_key)
      |'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,0.1)
      | beam.FlatMap(lambda x: x[1])
      | beam.Map(makeRow)
      | beam.Map(print))






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:924: FutureWarning: GroupIntoBatches is experimental.
#   return GroupIntoBatches(*_GroupIntoBatchesParams.parse_payload(proto))
# {'id': 'INSBI479746850', 'name': 'oFIDjzDZJ'}
# {'id': 'INSBI479746850', 'name': 'dfkhjgjzDZJ'}
# {'id': 'INSBI752381817', 'name': 'MNpdRhAYv'}
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip

# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip(('id','name'),x))
    return row


def insert_key(x):
    return (x[0][0:6],(x[0],x[1]))



import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

p = beam.Pipeline(options=options)
batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ') 
          
      ])
      |beam.Map(insert_key)
      |'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,0.1)
      | beam.FlatMap(lambda x: x[1])
      | beam.Map(makeRow)
      | "Write to Bigquery">>beam.io.Write(
                                               beam.io.WriteToBigQuery(
                                                                        'my-table-groupintobatches',
                                                                        dataset='gcpdataset',
                                                                        project='mimetic-parity-378803',
                                                                        schema='id:STRING,name:STRING',
                                                                        create_disposition=beam.io.BigQueryDisposition.CREATE_IF_NEEDED, #If table does not exist before, this code throws error
                                                                        write_disposition=beam.io.BigQueryDisposition.WRITE_APPEND
                                                                        
                                                                      )
                                                       ))






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip

# %%
#Create the Options first


import google.auth
from apache_beam.options.pipeline_options import PipelineOptions
from apache_beam.options.pipeline_options import GoogleCloudOptions
#from apache_beam.utils.pipeline_options import SetupOptions
from apache_beam.options.pipeline_options import StandardOptions

options = PipelineOptions()

#Setting the Options Programmatically
options = PipelineOptions(flags=[])

#set the project to the default project in your current Google Cloud Environment
_, options.view_as(GoogleCloudOptions).project=google.auth.default()

# Sets the pipeline mode to streaming, so we can stream the data from PubSub.
options.view_as(StandardOptions).streaming = True

options.view_as(GoogleCloudOptions).enable_streaming_engine = True
#options.view_as(PipelineOptions).experiments = 'use_runner_v2' the log says it is by deafult

#Set the Google Cloud Region in which Cloud Dataflow run
options.view_as(GoogleCloudOptions).region='us-west1'

#Cloud Storage Location
dataflow_gcs_location='gs://gcp-dataeng-demos-soumya/dataflow'

#Dataflow Staging Location. This location is used to stage the Dataflow Pipeline and SDK binary
options.view_as(GoogleCloudOptions).staging_location = '{}/staging'.format(dataflow_gcs_location)
#Dataflow Temp Location. This location is used to store temporary files or intermediate results before finally outputting
options.view_as(GoogleCloudOptions).temp_location = '{}/temp'.format(dataflow_gcs_location)
#The directory to store the output files of the job
output_gcs_location = '{}/output'.format(dataflow_gcs_location)


def makeRow(x):
    row = dict(zip(('id','name'),x))
    return row


def insert_key(x):
    return (x[0][0:6],(x[0],x[1]))



import apache_beam as beam
import time
from apache_beam.runners import DataflowRunner

with beam.Pipeline(options=options) as p:
  batches_with_keys = (
      p
      | 'Create produce' >> beam.Create([
          ('INSBI479746850', 'oFIDjzDZJ'),('INSBI752381817','MNpdRhAYv'),('INSBI479746850', 'dfkhjgjzDZJ') #somehow this code is writing 5 times into BQ instead 3
          
      ])
      |"window stream1">>beam.WindowInto(beam.window.FixedWindows(5))
      |beam.Map(insert_key)
      |'Group into batches' >> beam.GroupIntoBatches.WithShardedKey(2,5)
      |beam.Map(print)
      )






pipeline_result = DataflowRunner().run_pipeline(p, options=options)
# Out:
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:966: FutureWarning: GroupIntoBatches is experimental.
#   | GroupIntoBatches(
# /jupyter/.kernels/apache-beam-2.44.0/lib/python3.8/site-packages/apache_beam/transforms/util.py:924: FutureWarning: GroupIntoBatches is experimental.
#   return GroupIntoBatches(*_GroupIntoBatchesParams.parse_payload(proto))
# (('INSBI4', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), [('INSBI479746850', 'oFIDjzDZJ'), ('INSBI479746850', 'dfkhjgjzDZJ')])
# (('INSBI7', b'\x9f\xe5\xe8<\xf6\x9cNs\xb5kS\n\x89\xa6\xbbb\x00\x00\x7f\xc1\xe9\x7f\xe7\x00'), [('INSBI752381817', 'MNpdRhAYv')])
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: /jupyter/.kernels/apache-beam-2.44.0/bin/python -m pip install --upgrade pip
